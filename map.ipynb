# %%
# Import dependencies
import gmaps
import pandas as pd
from PIL import Image
# Import the API key.
from config import g_key

# %%
# read csv file as dataframe
nyc_bookstores_df = pd.read_csv('nyc_bookstores_location_images.csv')
nyc_bookstores_df
# Out:
#                            Name  \
# 0   Berl's Brooklyn Poetry Shop
# 1               Bookmark Shoppe
# 2               Books Are Magic
# 3               Cafe Con Libros
# 4                 Catland Books
# ..                          ...
# 63           Kew & Willow Books
# 64         Topos Bookstore Cafe
# 65         Turn the Page Again!
# 66    Everything Goes Book Cafe
# 67                  The Lit Bar
#
#                                           Address  \
# 0               141 Front St., Brooklyn, NY 11201
# 1                8415 3rd Ave, Brooklyn, NY 11209
# 2               225 Smith St., Brooklyn, NY 11231
# 3             724 Prospect Pl. Brooklyn, NY 11216
# 4            987 Flushing Ave, Brooklyn, NY 11206
# ..                                            ...
# 63    81-63 Lefferts Blvd, Kew Gardens\tNY, 11415
# 64         788 Woodward Ave., Ridgewood, NY 11385
# 65             39-15 Bell Blvd, Bayside, NY 11361
# 66           208 Bay St., Staten Island, NY 10301
# ...

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
info_box_template = """
<dl>
<dt>{Name}</dt><dd></dd>
<a href={Link}>Visit Website</a>
<img src={Full Image URL}/>
</dl>
"""

# %%
# Store the DataFrame Row.
popup_info = [info_box_template.format(**row) for index, row in nyc_bookstores_df.iterrows()]
popup_info
# Out:
# ["\n<dl>\n<dt>Berl's Brooklyn Poetry Shop</dt><dd></dd>\n<a href=http://www.berlspoetry.com/>Visit Website</a>\n<img src=http://www.berlspoetry.com/static1.squarespace.com/static/534deea3e4b051a0cfe3fed5/t/53c06279e4b0450591a497ed/1607135175706/?format=750w/>\n</dl>\n",
#  '\n<dl>\n<dt>Bookmark Shoppe</dt><dd></dd>\n<a href=https://www.bookmarkshoppe.com/>Visit Website</a>\n<img src=https://www.bookmarkshoppe.com/sites/bookmarkshoppe.com/files/TheBookMarkShoppe_Logo_2020_3.jpeg/>\n</dl>\n',
#  '\n<dl>\n<dt>Books Are Magic</dt><dd></dd>\n<a href=https://www.booksaremagic.net/>Visit Website</a>\n<img src=https://bookmanager.com/i/9903658/sitecontent/1499874639_twitter icon.jpg/>\n</dl>\n',
# ...

# %%
# Map
# Get the latitude and longitude.
locations = nyc_bookstores_df[["Latitudes","Longitudes"]]
new_york_coordinates = (40.75, -74.00)
fig = gmaps.figure(center=new_york_coordinates, zoom_level=10.5)
marker_layer = gmaps.marker_layer(locations, info_box_content = popup_info)
# bookstore_layer = gmaps.symbol_layer(locations, fill_color='blue', stroke_color='green', scale=3, info_box_content = popup_info)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
Img=Image.open('hello.png')

# %%
Img.show()
